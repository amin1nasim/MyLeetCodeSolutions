# %% [markdown]
# ![121-best%20time%20to%20buy%20and%20sell%20stock.PNG](attachment:121-best%20time%20to%20buy%20and%20sell%20stock.PNG)

# %%
# O(n)
class Solution:
    def maxProfit(self, prices: List[int]) -> int:
        buy = prices[0]
        result = 0
        for p in prices[1:]:
            if p > buy:
                result = max(result, p - buy)
            
            elif p < buy:
                buy = p
        return result

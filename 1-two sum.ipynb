# %% [markdown]
# ![1-two%20sum.PNG](attachment:1-two%20sum.PNG)

# %%
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        diffs = {}

        for idx, num in enumerate(nums):
            diff = target - num
            if diff in diffs:
                return [diffs[diff], idx]
            diffs[num] = idx

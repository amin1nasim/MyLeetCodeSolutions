# %% [markdown]
# ![191-number%20of%201%20bits.PNG](attachment:191-number%20of%201%20bits.PNG)

# %%
class Solution:
    def hammingWeight(self, n: int) -> int:
        result = 0
        while n > 0:
            result += n % 2
            n = n // 2
        return result
